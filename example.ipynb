# %% [markdown]
# # eurostat data cube

# %%
import netCDF4
import xarray as xr
import matplotlib.pyplot as plt

dt = xr.open_datatree("eurostat-datacube.nc")
dt.groups
# Out:
# ('/', '/edat_lfse_04', '/nama_10_nfa_bs')

# %%
a = dt["edat_lfse_04"]["edat_lfse_04_F_ED34_44_Y20-24"]
a
# Out:
# <xarray.DataArray 'edat_lfse_04_F_ED34_44_Y20-24' (geo: 1210, time: 56)> Size: 542kB
# [67760 values with dtype=float64]
# Coordinates:
#   * time     (time) <U7 2kB '2012-Q1' '2012-Q2' ... '2025-Q3' '2025-Q4'
#   * geo      (geo) <U5 24kB 'AT111' 'AT112' 'AT113' ... 'SK032' 'SK041' 'SK042'
# Attributes:
#     doi:        https://doi.org/10.2908/edat_lfse_04
#     long_name:  Population in private households (sex=F,isced11=ED34_44,age=Y...

# %%
a.sel(geo = "DEG03").plot()
