# %% [markdown]
# # eurostat data cube

# %%
import netCDF4
import xarray as xr
import matplotlib.pyplot as plt

dt = xr.open_datatree("eurostat-datacube.nc")
dt
# Out:
# getfattr: /home/dloos/prj/eurostat-datacube/eurostat-datacube.nc: Input/output error
# <xarray.DataTree>
# Group: /
# │   Dimensions:  (geo: 1210, time: 84)
# │   Coordinates:
# │     * geo      (geo) <U5 24kB 'AT111' 'AT112' 'AT113' ... 'SK032' 'SK041' 'SK042'
# │     * time     (time) datetime64[ns] 672B 2001-01-01 2001-04-01 ... 2021-10-01
# ├── Group: /demo_r_d3dens
# │       Dimensions:    (geo: 1210, time: 84)
# │       Data variables:
# │           a_per_km2  (geo, time) float64 813kB ...
# ├── Group: /nama_10r_3gdp
# │       Dimensions:              (geo: 1210, time: 84)
# │       Data variables:
# │           a_mio_eur            (geo, time) float64 813kB ...
# │           a_mio_nac            (geo, time) float64 813kB ...
# │           a_mio_pps_eu27_2020  (geo, time) float64 813kB ...
# ├── Group: /nama_10r_2gvagr
# │       Dimensions:         (geo: 1210, time: 84)
# │       Data variables:
# │           a_i20_b1g       (geo, time) float64 813kB ...
# ...

# %%
dt.demo_r_d3dens.a_per_km2
# Out:
# <xarray.DataArray 'a_per_km2' (geo: 1210, time: 84)> Size: 813kB
# [101640 values with dtype=float64]
# Coordinates:
#   * geo      (geo) <U5 24kB 'AT111' 'AT112' 'AT113' ... 'SK032' 'SK041' 'SK042'
#   * time     (time) datetime64[ns] 672B 2001-01-01 2001-04-01 ... 2021-10-01
# Attributes:
#     freq:       Annual
#     unit:       Persons per square kilometre
#     frac_na:    0.0484454939000394
#     long_name:  Population density in
#     title:      Population density by NUTS 3 region
#     doi:        https://doi.org/10.2908/demo_r_d3dens

# %%
dt.demo_r_d3dens.a_per_km2.sel(geo = "DEG03").plot()
