# %% [markdown]
# # eurostat data cube

# %%
import netCDF4
import xarray as xr
import matplotlib.pyplot as plt

dt = xr.open_datatree("eurostat-datacube.nc")
dt
# Out:
# <xarray.DataTree>
# Group: /
# │   Dimensions:  (geo: 1210, time: 56)
# │   Coordinates:
# │     * geo      (geo) <U5 24kB 'AT111' 'AT112' 'AT113' ... 'SK032' 'SK041' 'SK042'
# │     * time     (time) datetime64[ns] 448B 2012-01-01 2012-04-01 ... 2025-10-01
# ├── Group: /demo_r_d3dens
# │       Dimensions:    (geo: 1210, time: 56)
# │       Data variables:
# │           a_per_km2  (geo, time) float64 542kB ...
# ├── Group: /nama_10r_3gdp
# │       Dimensions:              (geo: 1210, time: 56)
# │       Data variables:
# │           a_eur_hab            (geo, time) float64 542kB ...
# │           a_eur_hab_eu27_2020  (geo, time) float64 542kB ...
# │           a_mio_eur            (geo, time) float64 542kB ...
# │           a_mio_nac            (geo, time) float64 542kB ...
# │           a_mio_pps_eu27_2020  (geo, time) float64 542kB ...
# │           a_pps_eu27_2020_hab  (geo, time) float64 542kB ...
# │           a_pps_hab_eu27_2020  (geo, time) float64 542kB ...
# ├── Group: /nama_10r_2gvagr
# │       Dimensions:         (geo: 1210, time: 56)
# │       Data variables:
# │           a_i20_b1g       (geo, time) float64 542kB ...
# │           a_i20_b1gq      (geo, time) float64 542kB ...
# │           a_pch_pre_b1g   (geo, time) float64 542kB ...
# │           a_pch_pre_b1gq  (geo, time) float64 542kB ...
# ├── Group: /nama_10r_3gva
# │       Dimensions:           (geo: 1210, time: 56)
# │       Data variables: (12/60)
# │           a_cp_meur_a       (geo, time) float64 542kB ...
# │           a_cp_meur_b_e     (geo, time) float64 542kB ...
# │           a_cp_meur_c       (geo, time) float64 542kB ...
# │           a_cp_meur_f       (geo, time) float64 542kB ...
# │           a_cp_meur_g_j     (geo, time) float64 542kB ...
# │           a_cp_meur_k_n     (geo, time) float64 542kB ...
# │           ...                ...
# │           a_pyp_mnac_l      (geo, time) float64 542kB ...
# │           a_pyp_mnac_m_n    (geo, time) float64 542kB ...
# │           a_pyp_mnac_o_q    (geo, time) float64 542kB ...
# │           a_pyp_mnac_o_u    (geo, time) float64 542kB ...
# │           a_pyp_mnac_r_u    (geo, time) float64 542kB ...
# │           a_pyp_mnac_total  (geo, time) float64 542kB ...
# ├── Group: /nama_10r_2gfcf
# │       Dimensions:                (geo: 1210, time: 56)
# │       Data variables: (12/40)
# │           a_mio_eur_a_s1         (geo, time) float64 542kB ...
# │           a_mio_eur_b_e_s1       (geo, time) float64 542kB ...
# │           a_mio_eur_c_s1         (geo, time) float64 542kB ...
# │           a_mio_eur_f_s1         (geo, time) float64 542kB ...
# │           a_mio_eur_g_i_s1       (geo, time) float64 542kB ...
# │           a_mio_eur_g_j_s1       (geo, time) float64 542kB ...
# │           ...                     ...
# │           a_mio_eur_total_s1314  (geo, time) float64 542kB ...
# │           a_mio_nac_total_s13    (geo, time) float64 542kB ...
# │           a_mio_nac_total_s1311  (geo, time) float64 542kB ...
# │           a_mio_nac_total_s1312  (geo, time) float64 542kB ...
# │           a_mio_nac_total_s1313  (geo, time) float64 542kB ...
# │           a_mio_nac_total_s1314  (geo, time) float64 542kB ...
# ├── Group: /nama_10r_2emhrw
# │       Dimensions:           (geo: 1210, time: 56)
# │       Data variables: (12/45)
# │           a_ths_a_emp       (geo, time) float64 542kB ...
# │           a_ths_a_sal       (geo, time) float64 542kB ...
# │           a_ths_a_self      (geo, time) float64 542kB ...
# │           a_ths_b_e_emp     (geo, time) float64 542kB ...
# │           a_ths_b_e_sal     (geo, time) float64 542kB ...
# │           a_ths_b_e_self    (geo, time) float64 542kB ...
# │           ...                ...
# │           a_ths_o_q_emp     (geo, time) float64 542kB ...
# │           a_ths_o_q_sal     (geo, time) float64 542kB ...
# │           a_ths_o_q_self    (geo, time) float64 542kB ...
# │           a_ths_r_u_emp     (geo, time) float64 542kB ...
# │           a_ths_r_u_sal     (geo, time) float64 542kB ...
# │           a_ths_r_u_self    (geo, time) float64 542kB ...
# ├── Group: /edat_lfse_04
# │       Dimensions:                (geo: 1210, time: 56)
# │       Data variables: (12/72)
# │           a_pc_y20_24_ed0_2_f    (geo, time) float64 542kB ...
# │           a_pc_y20_24_ed0_2_m    (geo, time) float64 542kB ...
# │           a_pc_y20_24_ed0_2_t    (geo, time) float64 542kB ...
# │           a_pc_y20_24_ed34_44_f  (geo, time) float64 542kB ...
# │           a_pc_y20_24_ed34_44_m  (geo, time) float64 542kB ...
# │           a_pc_y20_24_ed34_44_t  (geo, time) float64 542kB ...
# │           ...                     ...
# │           a_pc_y30_34_ed3_8_f    (geo, time) float64 542kB ...
# │           a_pc_y30_34_ed3_8_m    (geo, time) float64 542kB ...
# │           a_pc_y30_34_ed3_8_t    (geo, time) float64 542kB ...
# │           a_pc_y30_34_ed5_8_f    (geo, time) float64 542kB ...
# │           a_pc_y30_34_ed5_8_m    (geo, time) float64 542kB ...
# │           a_pc_y30_34_ed5_8_t    (geo, time) float64 542kB ...
# ├── Group: /lfst_r_lfu3pers
# │       Dimensions:                   (geo: 1210, time: 56)
# │       Data variables: (12/150)
# │           a_ths_per_y15_24_ed0_2_f  (geo, time) float64 542kB ...
# │           a_ths_per_y15_24_ed0_2_m  (geo, time) float64 542kB ...
# │           a_ths_per_y15_24_ed0_2_t  (geo, time) float64 542kB ...
# │           a_ths_per_y15_24_ed3_4_f  (geo, time) float64 542kB ...
# │           a_ths_per_y15_24_ed3_4_m  (geo, time) float64 542kB ...
# │           a_ths_per_y15_24_ed3_4_t  (geo, time) float64 542kB ...
# │           ...                        ...
# │           a_ths_per_y45_54_nrp_t    (geo, time) float64 542kB ...
# │           a_ths_per_y55_64_nrp_f    (geo, time) float64 542kB ...
# │           a_ths_per_y55_64_nrp_m    (geo, time) float64 542kB ...
# │           a_ths_per_y55_64_nrp_t    (geo, time) float64 542kB ...
# │           a_ths_per_y_ge15_nrp_f    (geo, time) float64 542kB ...
# │           a_ths_per_y_ge25_nrp_f    (geo, time) float64 542kB ...
# ├── Group: /nama_10_nfa_bs
# │       Dimensions:                   (geo: 1210, time: 56)
# │       Data variables: (12/250)
# │           a_cp_meur_n111n_s1        (geo, time) float64 542kB ...
# │           a_cp_meur_n1121n_s1       (geo, time) float64 542kB ...
# │           a_cp_meur_n1122n_s1       (geo, time) float64 542kB ...
# │           a_cp_meur_n112n_s1        (geo, time) float64 542kB ...
# │           a_cp_meur_n115n_s1        (geo, time) float64 542kB ...
# │           a_cp_meur_n1171n_s1       (geo, time) float64 542kB ...
# │           ...                        ...
# │           a_cp_mnac_n212n_s14_s15   (geo, time) float64 542kB ...
# │           a_cp_mnac_n215n_s14_s15   (geo, time) float64 542kB ...
# │           a_cp_mnac_n21n_s14_s15    (geo, time) float64 542kB ...
# │           a_cp_mnac_n21on_s14_s15   (geo, time) float64 542kB ...
# │           a_cp_mnac_n22n_s14_s15    (geo, time) float64 542kB ...
# │           a_cp_mnac_n23n_s14_s15    (geo, time) float64 542kB ...
# ├── Group: /teicp010
# │       Dimensions:         (geo: 1210, time: 56)
# │       Data variables:
# │           m_i25_cp01      (geo, time) float64 542kB ...
# │           m_pch_m12_cp01  (geo, time) float64 542kB ...
# │           m_pch_m1_cp01   (geo, time) float64 542kB ...
# ├── Group: /teicp250
# │       Dimensions:        (geo: 1210, time: 56)
# │       Data variables:
# │           m_i25_nrg      (geo, time) float64 542kB ...
# │           m_pch_m12_nrg  (geo, time) float64 542kB ...
# │           m_pch_m1_nrg   (geo, time) float64 542kB ...
# └── Group: /ilc_di11
#         Dimensions:         (geo: 1210, time: 56)
#         Data variables:
#             a_rat_total_f   (geo, time) float64 542kB ...
#             a_rat_total_m   (geo, time) float64 542kB ...
#             a_rat_total_t   (geo, time) float64 542kB ...
#             a_rat_y_ge65_f  (geo, time) float64 542kB ...
#             a_rat_y_ge65_m  (geo, time) float64 542kB ...
#             a_rat_y_ge65_t  (geo, time) float64 542kB ...
#             a_rat_y_lt65_f  (geo, time) float64 542kB ...
#             a_rat_y_lt65_m  (geo, time) float64 542kB ...
#             a_rat_y_lt65_t  (geo, time) float64 542kB ...

# %%
dt.demo_r_d3dens.a_per_km2
# Out:
# <xarray.DataArray 'a_per_km2' (geo: 1210, time: 56)> Size: 542kB
# [67760 values with dtype=float64]
# Coordinates:
#   * geo      (geo) <U5 24kB 'AT111' 'AT112' 'AT113' ... 'SK032' 'SK041' 'SK042'
#   * time     (time) datetime64[ns] 448B 2012-01-01 2012-04-01 ... 2025-10-01
# Attributes:
#     freq:       Annual
#     unit:       Persons per square kilometre
#     long_name:  Population density in
#     title:      Population density by NUTS 3 region
#     doi:        https://doi.org/10.2908/demo_r_d3dens

# %%
dt.demo_r_d3dens.a_per_km2.sel(geo = "DEG03").plot()
